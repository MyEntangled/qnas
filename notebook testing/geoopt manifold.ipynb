# %%
import torch.nn
import geoopt


# package.nn.modules.py
def create_ball(ball=None, c=None):
    """
    Helper to create a PoincareBall.
    Sometimes you may want to share a manifold across layers, e.g. you are using scaled PoincareBall.
    In this case you will require same curvature parameters for different layers or end up with nans.
    Parameters
    ----------
    ball : geoopt.PoincareBall
    c : float
    Returns
    -------
    geoopt.PoincareBall
    """
    if ball is None:
        assert c is not None, "curvature of the ball should be explicitly specified"
        ball = geoopt.PoincareBall(c)
    # else trust input
    return ball


class MobiusLinear(torch.nn.Linear):
    def __init__(self, *args, nonlin=None, ball=None, c=1.0, **kwargs):
        super().__init__(*args, **kwargs)
        # for manifolds that have parameters like Poincare Ball
        # we have to attach them to the closure Module.
        # It is hard to implement device allocation for manifolds in other case.
        self.ball = create_ball(ball, c)
        if self.bias is not None:
            self.bias = geoopt.ManifoldParameter(self.bias, manifold=self.ball)
        self.nonlin = nonlin
        self.reset_parameters()

    def forward(self, input):
        return mobius_linear(
            input,
            weight=self.weight,
            bias=self.bias,
            nonlin=self.nonlin,
            ball=self.ball,
        )

    @torch.no_grad()
    def reset_parameters(self):
        torch.nn.init.eye_(self.weight)
        self.weight.add_(torch.rand_like(self.weight).mul_(1e-3))
        if self.bias is not None:
            self.bias.zero_()


# package.nn.functional.py
def mobius_linear(input, weight, bias=None, nonlin=None, *, ball: geoopt.PoincareBall):
    output = ball.mobius_matvec(weight, input)
    if bias is not None:
        output = ball.mobius_add(output, bias)
    if nonlin is not None:
        output = ball.logmap0(output)
        output = nonlin(output)
        output = ball.expmap0(output)
    return output

# %%
classifier = MobiusLinear()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/k7/xbg0txh97kb_tz_4gnqjl7cm0000gn/T/ipykernel_86652/1728890561.py in <module>
# ----> 1 classifier = MobiusLinear()
#
# /var/folders/k7/xbg0txh97kb_tz_4gnqjl7cm0000gn/T/ipykernel_86652/3438313004.py in __init__(self, nonlin, ball, c, *args, **kwargs)
#      26 class MobiusLinear(torch.nn.Linear):
#      27     def __init__(self, *args, nonlin=None, ball=None, c=1.0, **kwargs):
# ---> 28         super().__init__(*args, **kwargs)
#      29         # for manifolds that have parameters like Poincare Ball
#      30         # we have to attach them to the closure Module.
#
# TypeError: __init__() missing 2 required positional arguments: 'in_features' and 'out_features'

# %%
class Distance2PoincareHyperplanes(torch.nn.Module):
    n = 0
    # 1D, 2D versions of this class ara available with a one line change
    # class Distance2PoincareHyperplanes2d(Distance2PoincareHyperplanes):
    #     n = 2

    def __init__(
        self,
        plane_shape: int,
        num_planes: int,
        signed=True,
        squared=False,
        *,
        ball,
        std=1.0,
    ):
        super().__init__()
        self.signed = signed
        self.squared = squared
        # Do not forget to save Manifold instance to the Module
        self.ball = ball
        self.plane_shape = geoopt.utils.size2shape(plane_shape)
        self.num_planes = num_planes

        # In a layer we create Manifold Parameters in the same way we do it for
        # regular pytorch Parameters, there is no difference. But geoopt optimizer
        # will recognize the manifold and adjust to it
        self.points = geoopt.ManifoldParameter(
            torch.empty(num_planes, plane_shape), manifold=self.ball
        )
        self.std = std
        # following best practives, a separate method to reset parameters
        self.reset_parameters()

    def forward(self, input):
        input_p = input.unsqueeze(-self.n - 1)
        points = self.points.permute(1, 0)
        points = points.view(points.shape + (1,) * self.n)

        distance = self.ball.dist2plane(
            x=input_p, p=points, a=points, signed=self.signed, dim=-self.n - 2
        )
        if self.squared and self.signed:
            sign = distance.sign()
            distance = distance ** 2 * sign
        elif self.squared:
            distance = distance ** 2
        return distance

    def extra_repr(self):
        return (
            "plane_shape={plane_shape}, "
            "num_planes={num_planes}, "
            .format(**self.__dict__)
        )

    @torch.no_grad()
    def reset_parameters(self):
        direction = torch.randn_like(self.points)
        direction /= direction.norm(dim=-1, keepdim=True)
        distance = torch.empty_like(self.points[..., 0]).normal_(std=self.std)
        self.points.set_(self.ball.expmap0(direction * distance.unsqueeze(-1)))

# %%
import torch
import torch.nn as nn
from torch.nn.utils.parametrizations import orthogonal

import geoopt

# %%
class UnitaryLinear(torch.nn.Module):
    def __init__(self, num_qubits):
        super().__init__()
        # for manifolds that have parameters like Poincare Ball
        # we have to attach them to the closure Module.
        # It is hard to implement device allocation for manifolds in other case.
        self.man = geoopt.Stiefel()
        self.dim = 2**num_qubits
        self.weight = geoopt.ManifoldParameter(torch.empty(self.dim,self.dim, dtype=torch.cfloat), manifold=geoopt.Stiefel())
        self.reset_parameters()

    def forward(self, input):
        return unitary_linear(
            input,
            weight=self.weight,
            man=self.man,
        )

    @torch.no_grad()
    def reset_parameters(self):
        torch.nn.init.eye_(self.weight)
        #self.weight.add_(torch.rand_like(self.weight).mul_(1e-3))

            
# package.nn.functional.py
def unitary_linear(input, weight,*, man:geoopt.Stiefel):
    #output = ball.mobius_matvec(weight, input)
    output = torch.matmul(weight, input.T).T
    return output

model = UnitaryLinear(num_qubits=1)
optimizer = geoopt.optim.RiemannianAdam(model.parameters(), lr=0.001)

# %%
for layer in model.named_parameters():
    print(layer)
# Out:
# ('weight', Parameter on Stiefel(canonical) manifold containing:
# tensor([[1.+0.j, 0.+0.j],
#         [0.+0.j, 1.+0.j]], requires_grad=True))

# %%
# class UnitaryModel(nn.Module):
#     def __init__(self, num_qubits):
#         super(UnitaryModel, self).__init__()
#         d = 2**num_qubits
#         #self.U = orthogonal(nn.Linear(d,d, bias=False, dtype=torch.cfloat), orthogonal_map=None)
#         #self.U = geoopt.ManifoldParameter(self.U.weight, manifold=geoopt.Stiefel())
        
        
#     def forward(self, x):
#         x = self.U(x)
#         return x
    
# model = UnitaryModel(num_qubits=1)
# optimizer = geoopt.optim.RiemannianAdam(model.parameters(), lr=0.01)

# %%
dummy_x = torch.tensor([[1,0]], dtype=torch.cfloat, requires_grad=True)
dummy_y = torch.tensor([[1,-1j]],dtype=torch.cfloat)/torch.sqrt(torch.tensor(2))
#dummy_x = torch.tensor([[1,0],[1,0],[1,0],[1,0]], dtype=torch.cfloat, requires_grad=True)
#dummy_y = torch.tensor([[1,0],[1,0],[1,0],[1,0]], dtype=torch.cfloat)


print(dummy_x)
print(dummy_y)
# Out:
# tensor([[1.+0.j, 0.+0.j]], requires_grad=True)
# tensor([[0.7071+0.0000j, -0.0000-0.7071j]])

# %%
len(output)
# Out:
# 1

# %%
def fidelity_loss(output, target, model, reg=1e-6):
    loss = 0
    print('output: ', output)
    print('target: ', target)
    for i in range(len(output)):
        inner_prod = torch.dot(output[i].T.conj(), target[i])
        #loss += inner_prod.conj() * inner_prod
        loss -= torch.abs(inner_prod)**2 / len(output)
    
    U = list(model.parameters())[0].detach()
    orth_constraint = torch.matmul(U,U.T.conj()) - torch.eye(U.shape[0])
    return loss + reg*orth_constraint.abs().sum()

loss = fidelity_loss(dummy_x, dummy_y, model, 0)
print(loss)
loss.backward()
# Out:
# output:  tensor([[1.+0.j, 0.+0.j]], requires_grad=True)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# tensor(-0.5000, grad_fn=<AddBackward0>)

# %%
NUM_EPOCHS = 1000
fidelity = torch.zeros(NUM_EPOCHS, dtype=torch.cfloat)

for i in range(NUM_EPOCHS):
    optimizer.zero_grad()
    output = model(dummy_x)
    loss = fidelity_loss(output, dummy_y, model, reg=0)
    loss.backward()
    optimizer.step()
    fidelity[i] = loss.detach()
# Out:
# output:  tensor([[-0.4162+5.7543e-06j, -0.9093-2.6339e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4180+5.7524e-06j, -0.9085-2.6469e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4198+5.7503e-06j, -0.9076-2.6600e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4217+5.7482e-06j, -0.9068-2.6730e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4235+5.7461e-06j, -0.9059-2.6860e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4253+5.7439e-06j, -0.9051-2.6989e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4271+5.7416e-06j, -0.9042-2.7119e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4289+5.7393e-06j, -0.9034-2.7248e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4307+5.7369e-06j, -0.9025-2.7378e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4325+5.7344e-06j, -0.9017-2.7507e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4343+5.7318e-06j, -0.9008-2.7636e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4361+5.7293e-06j, -0.8999-2.7765e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4379+5.7266e-06j, -0.8990-2.7893e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4397+5.7238e-06j, -0.8982-2.8022e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4415+5.7210e-06j, -0.8973-2.8150e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4433+5.7182e-06j, -0.8964-2.8278e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4451+5.7152e-06j, -0.8955-2.8406e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4469+5.7122e-06j, -0.8946-2.8534e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4487+5.7091e-06j, -0.8937-2.8661e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4505+5.7060e-06j, -0.8928-2.8788e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4522+5.7028e-06j, -0.8919-2.8915e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4540+5.6995e-06j, -0.8910-2.9042e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4558+5.6962e-06j, -0.8901-2.9169e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4576+5.6929e-06j, -0.8892-2.9296e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4594+5.6894e-06j, -0.8883-2.9422e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4611+5.6859e-06j, -0.8874-2.9548e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4629+5.6824e-06j, -0.8864-2.9674e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4647+5.6787e-06j, -0.8855-2.9800e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4665+5.6751e-06j, -0.8846-2.9926e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4682+5.6713e-06j, -0.8836-3.0051e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4700+5.6675e-06j, -0.8827-3.0176e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4718+5.6636e-06j, -0.8818-3.0301e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4735+5.6597e-06j, -0.8808-3.0426e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4753+5.6557e-06j, -0.8799-3.0550e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4770+5.6516e-06j, -0.8789-3.0675e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4788+5.6475e-06j, -0.8780-3.0799e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4805+5.6433e-06j, -0.8770-3.0922e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4823+5.6391e-06j, -0.8760-3.1046e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4841+5.6348e-06j, -0.8751-3.1169e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4858+5.6304e-06j, -0.8741-3.1293e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4875+5.6260e-06j, -0.8731-3.1415e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4893+5.6215e-06j, -0.8722-3.1538e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4910+5.6170e-06j, -0.8712-3.1660e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4928+5.6124e-06j, -0.8702-3.1783e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4945+5.6078e-06j, -0.8692-3.1905e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4963+5.6031e-06j, -0.8682-3.2026e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4980+5.5983e-06j, -0.8672-3.2148e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.4997+5.5935e-06j, -0.8662-3.2269e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.5015+5.5886e-06j, -0.8652-3.2390e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.5032+5.5836e-06j, -0.8642-3.2511e-06j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.
-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.7119-5.6242e-07j,  0.7023-5.6999e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.7105-5.6484e-07j,  0.7037-5.7016e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.7091-5.6730e-07j,  0.7052-5.7035e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.7077-5.6979e-07j,  0.7066-5.7057e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.7063-5.7232e-07j,  0.7080-5.7081e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.7049-5.7490e-07j,  0.7094-5.7109e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.7034-5.7751e-07j,  0.7108-5.7140e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.7020-5.8016e-07j,  0.7122-5.7173e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.7006-5.8285e-07j,  0.7136-5.7209e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6992-5.8558e-07j,  0.7150-5.7247e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6977-5.8835e-07j,  0.7164-5.7288e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6963-5.9117e-07j,  0.7178-5.7333e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6949-5.9405e-07j,  0.7192-5.7382e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6934-5.9698e-07j,  0.7206-5.7435e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6920-5.9997e-07j,  0.7220-5.7492e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6905-6.0301e-07j,  0.7234-5.7552e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6891-6.0610e-07j,  0.7247-5.7617e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6876-6.0924e-07j,  0.7261-5.7683e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6862-6.1242e-07j,  0.7275-5.7753e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6847-6.1565e-07j,  0.7289-5.7825e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6833-6.1891e-07j,  0.7302-5.7898e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6818-6.2220e-07j,  0.7316-5.7974e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6803-6.2552e-07j,  0.7330-5.8050e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6789-6.2887e-07j,  0.7343-5.8127e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6774-6.3225e-07j,  0.7357-5.8205e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6759-6.3566e-07j,  0.7370-5.8285e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6744-6.3909e-07j,  0.7384-5.8364e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6730-6.4254e-07j,  0.7397-5.8445e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6715-6.4601e-07j,  0.7411-5.8524e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6700-6.4950e-07j,  0.7424-5.8604e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6685-6.5301e-07j,  0.7437-5.8684e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6670-6.5653e-07j,  0.7451-5.8764e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6655-6.6010e-07j,  0.7464-5.8846e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6640-6.6371e-07j,  0.7477-5.8930e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6625-6.6735e-07j,  0.7491-5.9015e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6610-6.7102e-07j,  0.7504-5.9101e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6595-6.7472e-07j,  0.7517-5.9187e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6580-6.7844e-07j,  0.7530-5.9274e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6565-6.8221e-07j,  0.7543-5.9363e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])
# output:  tensor([[-0.6550-6.8600e-07j,  0.7557-5.9452e-07j]],
#        grad_fn=<PermuteBackward0>)
# target:  tensor([[0.7071+0.0000j, -0.0000-0.7071j]])

# %%
fidelity.abs()
# Out:
# tensor([0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000])

# %%
for layer in model.named_parameters():
    print(layer)
# Out:
# ('weight', Parameter on Stiefel(canonical) manifold containing:
# tensor([[-0.4162+5.7543e-06j,  0.9093+2.6338e-06j],
#         [-0.9093-2.6339e-06j, -0.4162+5.7544e-06j]], requires_grad=True))

# %%
U = model.state_dict()['weight']
print("Unitarity: ", torch.dist(U.T.conj() @ U, torch.eye(2)))
print(U)

print(fidelity_loss(model(dummy_x), dummy_y, model, reg=0))
# Out:
# Unitarity:  tensor(7.1770e-05)
# tensor([[-0.4162+5.7543e-06j,  0.9093+2.6338e-06j],
#         [-0.9093-2.6339e-06j, -0.4162+5.7544e-06j]])
# tensor(-0.5000, grad_fn=<AddBackward0>)

# %%
print(model(dummy_x))
print(dummy_y)
# Out:
# tensor([[7.3449e-01-6.7862e-01j, 1.8477e-06-1.2517e-06j],
#         [7.3449e-01-6.7862e-01j, 1.8477e-06-1.2517e-06j],
#         [7.3449e-01-6.7862e-01j, 1.8477e-06-1.2517e-06j],
#         [7.3449e-01-6.7862e-01j, 1.8477e-06-1.2517e-06j]],
#        grad_fn=<MmBackward0>)
# tensor([[1.+0.j, 0.+0.j],
#         [1.+0.j, 0.+0.j],
#         [1.+0.j, 0.+0.j],
#         [1.+0.j, 0.+0.j]])
