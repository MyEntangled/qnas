# %%
import pickle

# %%
with open('/Users/trongduong/Dropbox/URP project/Code/PQC_composer/gate_distance/all_core_distances.pkl', 'rb') as f:
    all_core_distances = pickle.load(f)

# %%
all_core_distances
# Out:
# {'h_h_1_s': 0.0,
#  'h_x_1_s': 0.3826834323650895,
#  'h_y_1_s': 0.707106781186547,
#  'h_z_1_s': 0.38268343236508956,
#  'h_rx_1_s': 0.49999999999999967,
#  'h_ry_1_s': 0.7071067811865475,
#  'h_rz_1_s': 0.49999999999999956,
#  'x_h_1_s': 0.3826834323650895,
#  'x_x_1_s': 0.0,
#  'x_y_1_s': 0.707106781186547,
#  'x_z_1_s': 0.7071067811865472,
#  'x_rx_1_s': 0.49999999999999967,
#  'x_ry_1_s': 0.7071067811865472,
#  'x_rz_1_s': 0.7071067811865471,
#  'y_h_1_s': 0.707106781186547,
#  'y_x_1_s': 0.707106781186547,
#  'y_y_1_s': 0.0,
#  'y_z_1_s': 0.7071067811865472,
#  'y_rx_1_s': 0.7071067811865474,
#  'y_ry_1_s': 0.4999999999999996,
#  'y_rz_1_s': 0.7071067811865471,
#  'z_h_1_s': 0.38268343236508956,
#  'z_x_1_s': 0.7071067811865472,
#  'z_y_1_s': 0.7071067811865472,
#  'z_z_1_s': 0.0,
#  'z_rx_1_s': 0.7071067811865475,
#  'z_ry_1_s': 0.7071067811865476,
#  'z_rz_1_s': 0.5,
#  'rx_h_1_s': 0.49999999999999967,
#  'rx_x_1_s': 0.49999999999999967,
#  'rx_y_1_s': 0.7071067811865474,
# ...

# %%
len(all_core_distances)
# Out:
# 2107

# %%
with open('/Users/trongduong/Dropbox/URP project/Code/PQC_composer/gate_distance/all_shape_distances.pkl', 'rb') as f:
    all_shape_distances = pickle.load(f)

# %%
all_shape_distances
# Out:
# {'h_h_1_s': 0,
#  'h_x_1_s': 0,
#  'h_y_1_s': 0,
#  'h_z_1_s': 0,
#  'h_rx_1_s': 100000.0,
#  'h_ry_1_s': 100000.0,
#  'h_rz_1_s': 100000.0,
#  'x_h_1_s': 0,
#  'x_x_1_s': 0,
#  'x_y_1_s': 0,
#  'x_z_1_s': 0,
#  'x_rx_1_s': 100000.0,
#  'x_ry_1_s': 100000.0,
#  'x_rz_1_s': 100000.0,
#  'y_h_1_s': 0,
#  'y_x_1_s': 0,
#  'y_y_1_s': 0,
#  'y_z_1_s': 0,
#  'y_rx_1_s': 100000.0,
#  'y_ry_1_s': 100000.0,
#  'y_rz_1_s': 100000.0,
#  'z_h_1_s': 0,
#  'z_x_1_s': 0,
#  'z_y_1_s': 0,
#  'z_z_1_s': 0,
#  'z_rx_1_s': 100000.0,
#  'z_ry_1_s': 100000.0,
#  'z_rz_1_s': 100000.0,
#  'rx_h_1_s': 100000.0,
#  'rx_x_1_s': 100000.0,
#  'rx_y_1_s': 100000.0,
#  'rx_z_1_s': 100000.0,
#  'rx_rx_1_s': 0,
#  'rx_ry_1_s': 0,
#  'rx_rz_1_s': 0,
#  'ry_h_1_s': 100000.0,
#  'ry_x_1_s': 100000.0,
#  'ry_y_1_s': 100000.0,
#  'ry_z_1_s': 100000.0,
#  'ry_rx_1_s': 0,
#  'ry_ry_1_s': 0,
#  'ry_rz_1_s': 0,
#  'rz_h_1_s': 100000.0,
#  'rz_x_1_s': 100000.0,
#  'rz_y_1_s': 100000.0,
#  'rz_z_1_s': 100000.0,
# ...

# %%
len(all_shape_distances)
# Out:
# 2107

# %%
all_shape_distances['rzz_rzz_4_s']
# Out:
# 0

# %%
''
